# %% [markdown]
# # Reproduce report figures
#
# This notebook is intentionally secondary. The authoritative reproducibility path is in `scripts/*.ps1`. Use this notebook only to inspect generated CSVs/images after running the scripts.

# %%
from pathlib import Path
import pandas as pd
fid_csv = Path('../outputs/repro/fid_results_smoke.csv')
if fid_csv.exists():
    display(pd.read_csv(fid_csv))
else:
    print('Run scripts/reproduce_fid.ps1 first.')
